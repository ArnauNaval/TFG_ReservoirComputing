# %%
from scipy.fft import fft
import numpy as np
import pandas as pd
import scipy
import scipy.io
import matplotlib.pyplot as plt
import scipy.signal as spsg

# %%
data = scipy.io.loadmat('dataSorted.mat')
data = data['out'] 
data = data.round(decimals=4)
datad = data[:,:,0,0]
print(f'Total of {datad.shape}' )
# Out:
# Total of (128, 508)

# %%
fft_datad = fft(datad)
f =  2048 * np.linspace(0,254, num=254)/508
#f = f.reshape(254,1)
print(f.shape)
# Out:
# (254,)

# %%
plt.figure(figsize=(22,5))
plt.xticks(f.astype(int),f.astype(int))
plt.rcParams['xtick.labelsize'] = 'small'

plt.plot(fft_datad.T[254:])
plt.show()
# Out:
# /home/arnaunaval/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
fs = 2048
low_freq = 40./fs
high_freq = 80./fs

# %%
sos = signal.butter(4, [200,400], 'bandpass', fs=2048, output='sos')
filtered = signal.sosfilt(sos, datad)
fft_filtered = fft(filtered)

# %%
b,a = spsg.iirfilter(3, [low_freq,high_freq], btype='bandpass', ftype='butter')
filtered_ts = spsg.filtfilt(b, a, datad, axis=1)
fft_filter = fft(filtered_ts)

# %%
plt.figure(figsize=(22,5))
plt.xticks(f.astype(int),f.astype(int))
plt.rcParams['xtick.labelsize'] = 'small'

plt.plot(fft_filter.T[254:])
plt.show()
# Out:
# /home/arnaunaval/.local/lib/python3.8/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
